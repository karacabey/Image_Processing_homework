# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/img.png",0)

# %%
for gamma in [3.0,4.0,5.0]:
    gamma_corrected = np.array(255*(img / 255) ** gamma, dtype = 'uint8')
    cv2_imshow(gamma_corrected)
    cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=555x370 at 0x7F09C5BFA2D0>
# <PIL.Image.Image image mode=L size=555x370 at 0x7F09C71E9990>
# <PIL.Image.Image image mode=L size=555x370 at 0x7F09C71E9C50>
