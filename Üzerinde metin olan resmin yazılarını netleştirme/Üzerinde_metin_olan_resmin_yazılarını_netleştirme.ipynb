# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
imagedata_original = cv2.imread('/content/img.png')

# %%
cv2_imshow(imagedata_original)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=555x370 at 0x7F09C5C46890>
# -1

# %%
sharpening_filter = np.array([[-1,-1,-1],
                              [-1,9,-1],
                              [-1,-1,-1]])

sharpened_image = cv2.filter2D(imagedata_original, -1, sharpening_filter)

cv2_imshow(sharpened_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=555x370 at 0x7F09C5B21690>
